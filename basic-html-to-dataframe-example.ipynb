# %%
import pandas as pd

url_ = "https://en.wikipedia.org/wiki/Research_stations_in_Antarctica"

df = pd.concat(pd.read_html(url_))
df
# Out:
#                                      Name                 Location  \
# 0               Amundsen–Scott South Pole  Geographical South Pole
# 1                               Arctowski       King George Island
# 2          Arrival Heights Laboratory[12]              Ross Island
# 3   Arrival Heights Satellite Station[12]              Ross Island
# 4                                 Artigas       King George Island
# ..                                    ...                      ...
# 0                                     NaN                      NaN
# 1                                     NaN                      NaN
# 2                                     NaN                      NaN
# 3                                     NaN                      NaN
# 4                                     NaN                      NaN
#
#           Country                           Admin.  Year est.  Max. persons  \
# 0   United States  United States Antarctic Program     1957.0         153.0
# ...
